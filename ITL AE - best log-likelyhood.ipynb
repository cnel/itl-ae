# %%
# %matplotlib inline
from __future__ import absolute_import
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(1337)  # for reproducibility

from sklearn.datasets import make_swiss_roll

from theano import function

from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten, Reshape, Layer
from keras.layers.convolutional import Convolution2D, MaxPooling2D, UpSampling2D
from keras.layers.normalization import BatchNormalization as BN
from keras.utils import np_utils
from keras import backend as K
from keras.callbacks import ModelCheckpoint
from keras.regularizers import l2

from seya.layers.variational import VariationalDense as VAE
from seya.layers.convolutional import GlobalPooling2D
from seya.utils import apply_model
from seya.layers.regularization import ITLRegularizer
from seya.parzen import ParzenWindows

from agnez import grid2d, embedding2dplot

batch_size = 100
nb_epoch = 100
code_size = 3

# input image dimensions
img_rows, img_cols = 28, 28
# number of convolutional filters to use
nb_filters = 32
# size of pooling area for max pooling
nb_pool = 2
# convolution kernel size
nb_conv = 7
nb_classes = 10

# the data, shuffled and split between tran and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(X_train.shape[0], 1, img_rows, img_cols)
X_test = X_test.reshape(X_test.shape[0], 1, img_rows, img_cols)
X_train = X_train.astype("float32").reshape((-1, 784))
X_test = X_test.astype("float32").reshape((-1, 784))
X_train /= 255
X_test /= 255

print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, nb_classes)
Y_test = np_utils.to_categorical(y_test, nb_classes)

X_valid = X_train[50000:]
Y_valid = Y_train[50000:]
X_train = X_train[:50000]
Y_train = Y_train[:50000]
# Out:
# Using Theano backend.
# X_train shape: (60000, 784)
# 60000 train samples
# 10000 test samples
# Using gpu device 0: GeForce GTX 680 (CNMeM is disabled)

# %%
from theano import tensor as T
from theano.sandbox.rng_mrg import MRG_RandomStreams as RandomStreams
rng = RandomStreams()

def swiss_roll(size, noise=1, rng=rng):
    u = rng.uniform(size=(size[0], 1))
    t = 1.5 * np.pi * (1 + 2 * u)
    x = t * T.cos(t)
    # y = 21 * u2
    z = t * T.sin(t)

    X = K.concatenate([x, z], axis=-1)
    X += noise * rng.uniform(size=(size[0], 2))
    t = np.squeeze(t)
    return X

def laplace(size, rng=rng):
    u = rng.uniform(size=size)
    sgn = T.switch(T.gt(rng.uniform(size=size), .5), -1, 1)
    X = T.log(1 - u) * sgn
    return X

from theano import as_op
import theano
def infer_shape_numpy_dot(node, input_shapes):
    print(node)
    return node

@as_op(itypes=[theano.tensor.TensorType('float32', 'vector')],
       otypes=[theano.tensor.dmatrix], infer_shape=infer_shape_numpy_dot)
def laplace(shape):
    return np.random.laplace(shape.astype('int')).astype('float32')

# %%
enc = Sequential()
enc.add(Dense(1000, input_dim=784))
enc.add(Activation('tanh'))
enc.add(BN())
enc.add(Dense(1000))
enc.add(Activation('tanh'))
enc.add(BN())

enc.add(Dense(code_size))
enc.add(Activation('linear'))

# Default prior is a guassian with mean=0, std=5
enc.add(ITLRegularizer(distance='euclidean', scale=1., ksize=5.,
#                       #distribution=swiss_roll
                      ))
#enc.add(VAE(code_size, 100))

# %%
dec = Sequential()

dec.add(Dense(1000, input_dim=code_size, activation='tanh'))
#dec.add(Activation('tanh'))
#dec.add(ITLRegularizer(distance='entropy', scale=1., ksize=5))
#dec.add(BN())
dec.add(Dense(1000, activation='tanh'))
#dec.add(Activation('tanh'))
#dec.add(BN())
#dec.add(ITLRegularizer(distance='entropy', scale=1., ksize=5))

dec.add(Dense(784))
dec.add(Activation('sigmoid'))

# %%
model = Sequential()
model.add(enc)
model.add(dec)

model.compile(loss='mse', optimizer='adam')

# %%
    cbk = ModelCheckpoint('itl.hdf5', save_best_only=True, verbose=True)

    #try:
    model.fit(X_train, X_train.reshape((-1, 784)), batch_size=batch_size, nb_epoch=100, verbose=2,
          validation_data=(X_valid, X_valid.reshape((-1, 784))),
          callbacks=[cbk]
         )
    #except:
    #pass
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 3s - loss: 0.0881 - val_loss: 0.0469
# Epoch 00000: val_loss improved from inf to 0.04692, saving model to itl.hdf5
# Epoch 2/100
# 3s - loss: 0.0478 - val_loss: 0.0399
# Epoch 00001: val_loss improved from 0.04692 to 0.03993, saving model to itl.hdf5
# Epoch 3/100
# 3s - loss: 0.0430 - val_loss: 0.0369
# Epoch 00002: val_loss improved from 0.03993 to 0.03686, saving model to itl.hdf5
# Epoch 4/100
# 3s - loss: 0.0404 - val_loss: 0.0354
# Epoch 00003: val_loss improved from 0.03686 to 0.03539, saving model to itl.hdf5
# Epoch 5/100
# 3s - loss: 0.0390 - val_loss: 0.0346
# Epoch 00004: val_loss improved from 0.03539 to 0.03457, saving model to itl.hdf5
# Epoch 6/100
# 3s - loss: 0.0380 - val_loss: 0.0337
# Epoch 00005: val_loss improved from 0.03457 to 0.03365, saving model to itl.hdf5
# Epoch 7/100
# 3s - loss: 0.0373 - val_loss: 0.0330
# Epoch 00006: val_loss improved from 0.03365 to 0.03297, saving model to itl.hdf5
# Epoch 8/100
# 3s - loss: 0.0367 - val_loss: 0.0322
# Epoch 00007: val_loss improved from 0.03297 to 0.03221, saving model to itl.hdf5
# Epoch 9/100
# 3s - loss: 0.0362 - val_loss: 0.0327
# Epoch 00008: val_loss did not improve
# Epoch 10/100
# 3s - loss: 0.0358 - val_loss: 0.0327
# Epoch 00009: val_loss did not improve
# Epoch 11/100
# 3s - loss: 0.0355 - val_loss: 0.0316
# Epoch 00010: val_loss improved from 0.03221 to 0.03165, saving model to itl.hdf5
# Epoch 12/100
# 3s - loss: 0.0350 - val_loss: 0.0314
# Epoch 00011: val_loss improved from 0.03165 to 0.03137, saving model to itl.hdf5
# Epoch 13/100
# 3s - loss: 0.0347 - val_loss: 0.0313
# Epoch 00012: val_loss improved from 0.03137 to 0.03127, saving model to itl.hdf5
# Epoch 14/100
# 3s - loss: 0.0345 - val_loss: 0.0313
# Epoch 00013: val_loss did not improve
# Epoch 15/100
# 3s - loss: 0.0342 - val_loss: 0.0310
# Epoch 00014: val_loss improved from 0.03127 to 0.03104, saving model to itl.hdf5
# Epoch 16/100
# 3s - loss: 0.0339 - val_loss: 0.0304
# Epoch 00015: val_loss improved from 0.03104 to 0.03040, saving model to itl.hdf5
# Epoch 17/100
# 3s - loss: 0.0337 - val_loss: 0.0305
# Epoch 00016: val_loss did not improve
# Epoch 18/100
# 3s - loss: 0.0335 - val_loss: 0.0303
# Epoch 00017: val_loss improved from 0.03040 to 0.03032, saving model to itl.hdf5
# Epoch 19/100
# 3s - loss: 0.0332 - val_loss: 0.0301
# Epoch 00018: val_loss improved from 0.03032 to 0.03008, saving model to itl.hdf5
# Epoch 20/100
# 3s - loss: 0.0330 - val_loss: 0.0300
# Epoch 00019: val_loss improved from 0.03008 to 0.02998, saving model to itl.hdf5
# Epoch 21/100
# 3s - loss: 0.0329 - val_loss: 0.0301
# Epoch 00020: val_loss did not improve
# Epoch 22/100
# 3s - loss: 0.0327 - val_loss: 0.0298
# Epoch 00021: val_loss improved from 0.02998 to 0.02982, saving model to itl.hdf5
# Epoch 23/100
# 3s - loss: 0.0325 - val_loss: 0.0301
# Epoch 00022: val_loss did not improve
# Epoch 24/100
# 3s - loss: 0.0324 - val_loss: 0.0301
# Epoch 00023: val_loss did not improve
# Epoch 25/100
# 3s - loss: 0.0322 - val_loss: 0.0298
# Epoch 00024: val_loss improved from 0.02982 to 0.02975, saving model to itl.hdf5
# Epoch 26/100
# 3s - loss: 0.0320 - val_loss: 0.0296
# Epoch 00025: val_loss improved from 0.02975 to 0.02963, saving model to itl.hdf5
# Epoch 27/100
# 3s - loss: 0.0319 - val_loss: 0.0297
# Epoch 00026: val_loss did not improve
# Epoch 28/100
# 3s - loss: 0.0318 - val_loss: 0.0296
# Epoch 00027: val_loss improved from 0.02963 to 0.02956, saving model to itl.hdf5
# Epoch 29/100
# 3s - loss: 0.0316 - val_loss: 0.0296
# Epoch 00028: val_loss improved from 0.02956 to 0.02955, saving model to itl.hdf5
# Epoch 30/100
# 3s - loss: 0.0314 - val_loss: 0.0295
# Epoch 00029: val_loss improved from 0.02955 to 0.02953, saving model to itl.hdf5
# Epoch 31/100
# 3s - loss: 0.0313 - val_loss: 0.0296
# Epoch 00030: val_loss did not improve
# Epoch 32/100
# 3s - loss: 0.0313 - val_loss: 0.0296
# Epoch 00031: val_loss did not improve
# Epoch 33/100
# 3s - loss: 0.0311 - val_loss: 0.0293
# Epoch 00032: val_loss improved from 0.02953 to 0.02935, saving model to itl.hdf5
# Epoch 34/100
# 3s - loss: 0.0310 - val_loss: 0.0294
# Epoch 00033: val_loss did not improve
# Epoch 35/100
# 3s - loss: 0.0310 - val_loss: 0.0294
# Epoch 00034: val_loss did not improve
# Epoch 36/100
# 3s - loss: 0.0309 - val_loss: 0.0296
# Epoch 00035: val_loss did not improve
# Epoch 37/100
# 3s - loss: 0.0308 - val_loss: 0.0293
# Epoch 00036: val_loss improved from 0.02935 to 0.02926, saving model to itl.hdf5
# Epoch 38/100
# 3s - loss: 0.0307 - val_loss: 0.0294
# Epoch 00037: val_loss did not improve
# Epoch 39/100
# 3s - loss: 0.0306 - val_loss: 0.0300
# Epoch 00038: val_loss did not improve
# Epoch 40/100
# 3s - loss: 0.0306 - val_loss: 0.0296
# Epoch 00039: val_loss did not improve
# Epoch 41/100
# 3s - loss: 0.0305 - val_loss: 0.0293
# Epoch 00040: val_loss did not improve
# Epoch 42/100
# 3s - loss: 0.0303 - val_loss: 0.0296
# Epoch 00041: val_loss did not improve
# Epoch 43/100
# 3s - loss: 0.0303 - val_loss: 0.0294
# Epoch 00042: val_loss did not improve
# Epoch 44/100
# 3s - loss: 0.0301 - val_loss: 0.0293
# Epoch 00043: val_loss did not improve
# Epoch 45/100
# 3s - loss: 0.0301 - val_loss: 0.0296
# Epoch 00044: val_loss did not improve
# Epoch 46/100
# 3s - loss: 0.0301 - val_loss: 0.0296
# Epoch 00045: val_loss did not improve
# Epoch 47/100
# 3s - loss: 0.0300 - val_loss: 0.0297
# Epoch 00046: val_loss did not improve
# Epoch 48/100
# 3s - loss: 0.0299 - val_loss: 0.0292
# Epoch 00047: val_loss improved from 0.02926 to 0.02922, saving model to itl.hdf5
# Epoch 49/100
# 3s - loss: 0.0298 - val_loss: 0.0296
# Epoch 00048: val_loss did not improve
# Epoch 50/100
# 3s - loss: 0.0298 - val_loss: 0.0295
# Epoch 00049: val_loss did not improve
# Epoch 51/100
# 3s - loss: 0.0298 - val_loss: 0.0293
# Epoch 00050: val_loss did not improve
# Epoch 52/100
# 3s - loss: 0.0297 - val_loss: 0.0297
# Epoch 00051: val_loss did not improve
# Epoch 53/100
# 3s - loss: 0.0296 - val_loss: 0.0296
# Epoch 00052: val_loss did not improve
# Epoch 54/100
# 3s - loss: 0.0296 - val_loss: 0.0296
# Epoch 00053: val_loss did not improve
# Epoch 55/100
# 3s - loss: 0.0297 - val_loss: 0.0301
# Epoch 00054: val_loss did not improve
# Epoch 56/100
# 3s - loss: 0.0295 - val_loss: 0.0299
# Epoch 00055: val_loss did not improve
# Epoch 57/100
# 3s - loss: 0.0294 - val_loss: 0.0296
# Epoch 00056: val_loss did not improve
# Epoch 58/100
# 3s - loss: 0.0295 - val_loss: 0.0296
# Epoch 00057: val_loss did not improve
# Epoch 59/100
# 3s - loss: 0.0293 - val_loss: 0.0298
# Epoch 00058: val_loss did not improve
# Epoch 60/100
# 3s - loss: 0.0292 - val_loss: 0.0296
# Epoch 00059: val_loss did not improve
# Epoch 61/100
# 3s - loss: 0.0292 - val_loss: 0.0295
# Epoch 00060: val_loss did not improve
# Epoch 62/100
# 3s - loss: 0.0292 - val_loss: 0.0295
# Epoch 00061: val_loss did not improve
# Epoch 63/100
# 3s - loss: 0.0292 - val_loss: 0.0301
# Epoch 00062: val_loss did not improve
# Epoch 64/100
# 3s - loss: 0.0291 - val_loss: 0.0297
# Epoch 00063: val_loss did not improve
# Epoch 65/100
# 3s - loss: 0.0289 - val_loss: 0.0298
# Epoch 00064: val_loss did not improve
# Epoch 66/100
# 3s - loss: 0.0292 - val_loss: 0.0295
# Epoch 00065: val_loss did not improve
# Epoch 67/100
# 3s - loss: 0.0289 - val_loss: 0.0295
# Epoch 00066: val_loss did not improve
# Epoch 68/100
# 3s - loss: 0.0290 - val_loss: 0.0297
# Epoch 00067: val_loss did not improve
# Epoch 69/100
# 3s - loss: 0.0290 - val_loss: 0.0299
# Epoch 00068: val_loss did not improve
# Epoch 70/100
# 3s - loss: 0.0287 - val_loss: 0.0298
# Epoch 00069: val_loss did not improve
# Epoch 71/100
# 3s - loss: 0.0288 - val_loss: 0.0296
# Epoch 00070: val_loss did not improve
# Epoch 72/100
# 3s - loss: 0.0287 - val_loss: 0.0297
# Epoch 00071: val_loss did not improve
# Epoch 73/100
# 3s - loss: 0.0288 - val_loss: 0.0299
# Epoch 00072: val_loss did not improve
# Epoch 74/100
# 3s - loss: 0.0288 - val_loss: 0.0301
# Epoch 00073: val_loss did not improve
# Epoch 75/100
# 3s - loss: 0.0287 - val_loss: 0.0299
# Epoch 00074: val_loss did not improve
# Epoch 76/100
# 3s - loss: 0.0286 - val_loss: 0.0300
# Epoch 00075: val_loss did not improve
# Epoch 77/100
# 3s - loss: 0.0287 - val_loss: 0.0300
# Epoch 00076: val_loss did not improve
# Epoch 78/100
# 3s - loss: 0.0285 - val_loss: 0.0298
# Epoch 00077: val_loss did not improve
# Epoch 79/100
# 3s - loss: 0.0286 - val_loss: 0.0299
# Epoch 00078: val_loss did not improve
# Epoch 80/100
# 3s - loss: 0.0286 - val_loss: 0.0305
# Epoch 00079: val_loss did not improve
# Epoch 81/100
# 3s - loss: 0.0285 - val_loss: 0.0298
# Epoch 00080: val_loss did not improve
# Epoch 82/100
# 3s - loss: 0.0284 - val_loss: 0.0298
# Epoch 00081: val_loss did not improve
# Epoch 83/100
# 3s - loss: 0.0284 - val_loss: 0.0299
# Epoch 00082: val_loss did not improve
# Epoch 84/100
# 3s - loss: 0.0284 - val_loss: 0.0301
# Epoch 00083: val_loss did not improve
# Epoch 85/100
# 3s - loss: 0.0284 - val_loss: 0.0299
# Epoch 00084: val_loss did not improve
# Epoch 86/100
# 3s - loss: 0.0283 - val_loss: 0.0301
# Epoch 00085: val_loss did not improve
# Epoch 87/100
# 3s - loss: 0.0284 - val_loss: 0.0302
# Epoch 00086: val_loss did not improve
# Epoch 88/100
# 3s - loss: 0.0284 - val_loss: 0.0299
# Epoch 00087: val_loss did not improve
# Epoch 89/100
# 3s - loss: 0.0283 - val_loss: 0.0301
# Epoch 00088: val_loss did not improve
# Epoch 90/100
# 3s - loss: 0.0282 - val_loss: 0.0301
# Epoch 00089: val_loss did not improve
# Epoch 91/100
# 3s - loss: 0.0282 - val_loss: 0.0299
# Epoch 00090: val_loss did not improve
# Epoch 92/100
# 3s - loss: 0.0282 - val_loss: 0.0302
# Epoch 00091: val_loss did not improve
# Epoch 93/100
# 3s - loss: 0.0281 - val_loss: 0.0306
# Epoch 00092: val_loss did not improve
# Epoch 94/100
# 3s - loss: 0.0282 - val_loss: 0.0303
# Epoch 00093: val_loss did not improve
# Epoch 95/100
# 3s - loss: 0.0281 - val_loss: 0.0297
# Epoch 00094: val_loss did not improve
# Epoch 96/100
# 3s - loss: 0.0281 - val_loss: 0.0306
# Epoch 00095: val_loss did not improve
# Epoch 97/100
# 3s - loss: 0.0280 - val_loss: 0.0299
# Epoch 00096: val_loss did not improve
# Epoch 98/100
# 3s - loss: 0.0280 - val_loss: 0.0304
# Epoch 00097: val_loss did not improve
# Epoch 99/100
# 3s - loss: 0.0280 - val_loss: 0.0304
# Epoch 00098: val_loss did not improve
# Epoch 100/100
# 3s - loss: 0.0280 - val_loss: 0.0304
# Epoch 00099: val_loss did not improve

# %% [markdown]
# # Load best model

# %%
#model.load_weights('itl.hdf5')

# %% [markdown]
# # Sample (for visualization purposes)

# %%
X = K.placeholder(ndim=2)
Y = dec(X)
F = function([X], Y, allow_input_downcast=True)

# %%
plt.figure(figsize=(8, 8))
x = np.random.normal(0, 5, size=(144, code_size))
# x = np.random.uniform(-10, 10, size=(100, code_size))
#x = make_swiss_roll(100, noise=1.)[0]; x = x[:, [0, 2]]
#x = np.random.laplace(size=(100, code_size))
print(x.shape)
y = F(x)
I = grid2d(y.reshape((-1, 784)))
plt.imshow(-I, cmap='gray')
plt.axis('off')
# Out:
# (144, 3)
# (-0.5, 348.5, 348.5, -0.5)

# %% [markdown]
# # Visualize first layer

# %%
W = np.asarray(K.eval(enc.layers[0].W)).T
I = grid2d(W[:100])

# %%
plt.imshow(I)

# %% [markdown]
# # Visualize last layer

# %%
W = np.asarray(K.eval(dec.layers[-2].W))
I = grid2d(W[:100])

# %%
plt.imshow(I)

# %% [markdown]
# # Log-likelihood

# %% [markdown]
# Protocol:
#
# We need to figure the best sigma (kernel size for the Parzen estimator) here. We sample randomly from the model
# and test several values of sigma on the validation dataset (X_valid). The one with best results should be applied to the test set (X_test).

# %%
samples = np.zeros((10000, 784))
for i in range(100):
    x = np.random.normal(0, 5, size=(100, code_size))
    #x = make_swiss_roll(10000, noise=1.)[0]; x = x[:, [0, 2]]
    #x = np.random.laplace(size=(100, code_size))
    y = F(x)
    #y -= y.min()
    #y /= y.max()
    samples[i*100:(i+1)*100] = y

# %%
pw = ParzenWindows(samples=samples, sigma=.16)

# %%
pw.get_ll(X_test)
# Out:
# 300.27303261578083

# %%
nll = []
sigmas = np.arange(.01, 5, .05)
for s in sigmas:
    pw = ParzenWindows(samples=samples, sigma=s)
    v = pw.get_ll(X_valid) 
    nll.append(v)
    print(v)

# %%
best_s = sigmas[np.asarray(nll).argmax()]
pw = ParzenWindows(samples=samples, sigma=best_s)
pw.get_ll(X_test)

# %%
best_s

# %%
# repeat best 10 times

mcruns = np.zeros(10)
for k in range(10):
    samples = np.zeros((10000, 784))
    for i in range(100):
        x = np.random.normal(0, 5, size=(100, code_size))
        #x = make_swiss_roll(10000, noise=1.)[0]; x = x[:, [0, 2]]
        #x = np.random.laplace(size=(100, code_size))
        y = F(x)
        #y -= y.min()
        #y /= y.max()
        samples[i*100:(i+1)*100] = y
    best_s = sigmas[np.asarray(nll).argmax()]
    pw = ParzenWindows(samples=samples, sigma=best_s)
    mcruns[k] = pw.get_ll(X_test) 

print(mcruns.mean())
print(mcruns.std())
